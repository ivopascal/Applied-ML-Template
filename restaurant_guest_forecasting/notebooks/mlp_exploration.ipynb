# %%
import sys
import os

# Go up 2 levels: from notebooks/ → restaurant_guest_forecasting/ → project root
project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
import torch
import pandas as pd
import numpy as np

from restaurant_guest_forecasting.data.train_test_split import train_val_test_data

# %%
train_data_regression, val_data_regression, test_data_regression =\
      train_val_test_data(regression=True)

train_data_classification, val_data_classification, test_data_classification =\
      train_val_test_data(regression=False)

# %%
print(train_data_regression.columns)
print(train_data_classification.columns)

article_cols = [col for col in train_data_classification.columns if col.startswith("art")]
print(len(article_cols))
# Out:
# Index(['Date', 'GUESTS', 'is_Friday', 'is_Monday', 'is_Saturday', 'is_Sunday',
#        'is_Thursday', 'is_Tuesday', 'is_Wednesday', 'tempmax', 'tempmin',
#        'temp', 'feelslikemax', 'feelslikemin', 'feelslike', 'humidity',
#        'precip', 'precipprob', 'windgust', 'windspeed', 'cloudcover',
#        'solarradiation', 'uvindex', 'rain', 'snow', 'IsHoliday',
#        'Ascension Day', 'Christmas', 'Day of German Unity', 'Easter Monday',
#        'Good Friday', 'King's Day', 'May Day', 'New Year's Day',
#        'Second Christmas Day', 'Whit Monday'],
#       dtype='object')
# Index(['Date', 'is_Friday', 'is_Monday', 'is_Saturday', 'is_Sunday',
#        'is_Thursday', 'is_Tuesday', 'is_Wednesday', 'tempmax', 'tempmin',
#        'temp', 'feelslikemax', 'feelslikemin', 'feelslike', 'humidity',
#        'precip', 'precipprob', 'windgust', 'windspeed', 'cloudcover',
#        'solarradiation', 'uvindex', 'rain', 'snow', 'IsHoliday',
# ...
